# %% [markdown]
# <a href="https://colab.research.google.com/github/alyssaiapalucci4/colab-git-assignment2-AI/blob/main/Lesson_3_assignment_Alyssa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Assignment 3: Python Refresher
#
# Name: Alyssa Iapalucci
# Date: June 18th, 2026

# %%
# Python Library Management System

# Install required libraries (This should already exist in colab)
# !pip install requests

import pickle
import sqlite3
import requests

# 1. Data Types and Variables
book_title = "Python Programming"
book_quantity = 5
book_price = 29.99
is_available = True

print(f"Book: {book_title}, Quantity: {book_quantity}, Price: ${book_price}, Available: {is_available}")
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2026.5.20)
# Book: Python Programming, Quantity: 5, Price: $29.99, Available: True

# %%
# 2. Lists
books = ["Python Basics", "Advanced Python", "Data Science with Python"]

# Adding two more books
books.append("Machine Learning with Python")
books.insert(1, "Python for Beginners")

print("Updated book list:", books)
# Out:
# Updated book list: ['Python Basics', 'Python for Beginners', 'Advanced Python', 'Data Science with Python', 'Machine Learning with Python']

# %%
# 3. Loops and range()
print("\nAvailable books:")

# Print books with index numbers
for i in range(len(books)):
    print(i, "-", books[i])
# Out:
# Available books:
# 0 - Python Basics
# 1 - Python for Beginners
# 2 - Advanced Python
# 3 - Data Science with Python
# 4 - Machine Learning with Python

# %%
# 4. User Input
new_book = input("Enter a new book title: ")

# Check if user entered something
if new_book.strip() != "":
    books.append(new_book)
    print("Updated book list:", books)
else:
    print("No book title entered.")
# Out:
# Enter a new book title: Python Basics
# Updated book list: ['Python Basics', 'Python for Beginners', 'Advanced Python', 'Data Science with Python', 'Machine Learning with Python', 'Python Basics']

# %%
# 5. Functions and Conditional Statements
def check_availability(book_name):
    # Check if the book exists in the list
    if book_name in books:
        return True
    else:
        return False


# Test the function
print(f"Is 'Python Basics' available? {check_availability('Python Basics')}")
print(f"Is 'Harry Potter' available? {check_availability('Harry Potter')}")
# Out:
# Is 'Python Basics' available? True
# Is 'Harry Potter' available? False

# %%
# 6. File I/O
def save_books_to_file(filename):
    try:
        with open(filename, 'w') as f:
            for book in books:
                f.write(f"{book}\n")
        print("Books saved successfully.")
    except Exception as e:
        print("Error saving file:", e)


# Function to read books from a file
def read_books_from_file(filename):
    try:
        with open(filename, 'r') as f:
            book_list = f.readlines()
            return [book.strip() for book in book_list]
    except FileNotFoundError:
        print("File not found.")
        return []


# Test file I/O
save_books_to_file("books.txt")
print("Books from file:", read_books_from_file("books.txt"))

# !cat books.txt  # Display file contents in Colab
# Out:
# Books saved successfully.
# Books from file: ['Python Basics', 'Python for Beginners', 'Advanced Python', 'Data Science with Python', 'Machine Learning with Python', 'Python Basics']
# Python Basics
# Python for Beginners
# Advanced Python
# Data Science with Python
# Machine Learning with Python
# Python Basics

# %%
# 7. Pickle for serialization
def save_books_pickle(filename):
    try:
        with open(filename, 'wb') as f:
            pickle.dump(books, f)
        print("Books saved to pickle file.")
    except Exception as e:
        print("Error saving pickle file:", e)


# Function to load books using pickle
def load_books_pickle(filename):
    try:
        with open(filename, 'rb') as f:
            return pickle.load(f)
    except FileNotFoundError:
        print("Pickle file not found.")
        return []


# Test pickle functions
save_books_pickle("books.pkl")
print("Books loaded from pickle:", load_books_pickle("books.pkl"))
# Out:
# Books saved to pickle file.
# Books loaded from pickle: ['Python Basics', 'Python for Beginners', 'Advanced Python', 'Data Science with Python', 'Machine Learning with Python', 'Python Basics']

# %%
# 8. SQLite Database Interaction
def create_books_table():
    try:
        conn = sqlite3.connect('library.db')
        cursor = conn.cursor()

        cursor.execute('''
            CREATE TABLE IF NOT EXISTS books
            (id INTEGER PRIMARY KEY, title TEXT, quantity INTEGER)
        ''')

        conn.commit()
        conn.close()
        print("Database table created.")
    except Exception as e:
        print("Database error:", e)

# Function to add a book to the database
def add_book_to_db(title, quantity):
    try:
        conn = sqlite3.connect('library.db')
        cursor = conn.cursor()

        cursor.execute(
            "INSERT INTO books (title, quantity) VALUES (?, ?)",
            (title, quantity)
        )

        conn.commit()
        conn.close()
        print(f"Book '{title}' added to database.")
    except Exception as e:
        print("Error adding book:", e)

# Test database functions
create_books_table()
add_book_to_db("Python for Beginners", 10)
# Out:
# Database table created.
# Book 'Python for Beginners' added to database.

# %%
# 9. Web API Interaction (GitHub API)
def get_python_repos():
    try:
        url = "https://api.github.com/search/repositories"
        params = {"q": "language:python", "sort": "stars", "order": "desc"}

        response = requests.get(url, params=params)

        # Check if request was successful
        if response.status_code == 200:
            data = response.json()
            return [repo['name'] for repo in data['items'][:5]]
        else:
            print("Error fetching data from API.")
            return []

    except Exception as e:
        print("API error:", e)
        return []


# Test API function
print("Top 5 Python repositories on GitHub:", get_python_repos())

print("\nLibrary Management System operations completed.")
# Out:
# Top 5 Python repositories on GitHub: ['public-apis', 'free-programming-books', 'system-design-primer', 'awesome-python', 'Python']
#
# Library Management System operations completed.
